# 132   1439.705882   534.941176         2.69                  74
# 133   1445.815126   536.848739         2.69                  75
# 134   1451.924370   538.756303         2.69                  76
# 135   1458.033613   540.663866         2.70                  77
# 136   1464.142857   470.000000         3.12                  78
# 137   1470.252101   379.000000         3.88                  79
# 138   1476.361345   575.000000         2.57                  80
# 139   1482.470588   367.000000         4.04                  81
# 140   1488.579832   502.000000         2.97                  82
# 141   1494.689076   552.109244         2.71                  83
# 142   1500.798319   554.016807         2.71                  84
# 143   1506.907563   555.924370         2.71                  85
# 144   1513.016807   557.831933         2.71                  86
# 145   1519.126050   559.739496         2.71                  87
# 146   1525.235294   575.000000         2.65                  88
# 147   1531.344538   367.000000         4.17                  89
# 148   1537.453782   502.000000         3.06                  90
# 149   1543.563025   374.000000         4.13                  91
# 150   1549.672269   575.000000         2.70                  92
# 151   1555.781513   348.000000         4.47                  93
# 152   1561.890756   398.000000         3.92                  94

# %%
# Assuming your DataFrame is named 'df'
row_index = 34  # Change this to the index of the row you want to modify

# Changing the value in the 4th column for the specific row
new_value = 0 # Replace this with the new value you want to assign
df.loc[row_index, 'Degree_of_diseas %'] = new_value  # Replace 'Column_Name' with the actual name of the column

# Print the DataFrame to verify the change
print(df.to_string())
# Out:
#      Sum_of_humid  sum_of_temp  him_by_temp  Degree_of_diseas %
# 0      869.000000   429.000000         2.03                   0
# 1      938.000000   470.000000         2.00                   0
# 2     1542.000000   379.000000         4.07                  68
# 3      852.000000   575.000000         1.48                   0
# 4     1503.000000   367.000000         4.10                  58
# 5     1151.000000   502.000000         2.29                  53
# 6     1437.000000   374.000000         3.84                  61
# 7      841.000000   575.000000         1.46                   0
# 8     1568.000000   348.000000         4.51                  93
# 9     1255.000000   398.000000         3.15                  73
# 10    1119.000000   438.000000         2.55                   0
# 11    1254.000000   469.000000         2.67                   0
# 12     949.000000   471.000000         2.01                   0
# 13    1325.000000   433.000000         3.06                  50
# 14    1158.000000   373.000000         3.10                  70
# 15     841.000000   348.000000         2.42                  52
# 16    1437.000000   359.947368         3.99                  80
# 17     841.000000   371.894737         2.26                  55
# 18    1568.000000   383.842105         4.09                   0
# 19     994.052632   395.789474         2.51                  65
# 20    1032.315789   407.736842         2.53                   0
# 21    1542.000000   419.684211         3.67                  67
# 22     852.000000   431.631579         1.97                  81
# 23    1503.000000   443.578947         3.39                  66
# 24    1185.368421   455.526316         2.60                   0
# 25    1223.631579   467.473684         2.62                   0
# 26    1261.894737   479.421053         2.63                   0
# 27    1300.157895   491.368421         2.65                   0
# 28    1338.421053   503.315789         2.66                   0
# 29    1376.684211   515.263158         2.67                   0
# 30    1414.947368   527.210526         2.68                   0
# 31    1453.210526   539.157895         2.70                   0
# 32    1491.473684   551.105263         2.71                   0
# 33    1529.736842   563.052632         2.72                   0
# 34    1568.000000   575.000000         2.73                   0
# 35    1437.000000   349.907563         4.11                  78
# 36     841.000000   351.815126         2.39                  75
# 37    1568.000000   353.722689         4.43                   0
# 38     865.436975   355.630252         2.43                  67
# 39    1542.000000   357.537815         4.31                   0
# 40     852.000000   359.445378         2.37                  80
# 41    1503.000000   361.352941         4.16                   0
# 114   1437.000000   500.605042         2.87                  56
# 115    841.000000   502.512605         1.67                  57
# 116   1568.000000   504.420168         3.11                  58
# 117   1348.067227   506.327731         2.66                  59
# 118   1354.176471   508.235294         2.66                  60
# 119   1360.285714   510.142857         2.67                  61
# 120   1366.394958   512.050420         2.67                  62
# 121   1372.504202   513.957983         2.67                  63
# 122   1378.613445   515.865546         2.67                  64
# 123   1384.722689   517.773109         2.67                  65
# 124   1390.831933   519.680672         2.68                  66
# 125   1396.941176   521.588235         2.68                  67
# 126   1403.050420   523.495798         2.68                  68
# 127   1409.159664   525.403361         2.68                  69
# 128   1415.268908   527.310924         2.68                  70
# 129   1421.378151   529.218487         2.69                  71
# 130   1427.487395   531.126050         2.69                  72
# 131   1433.596639   533.033613         2.69                  73
# 132   1439.705882   534.941176         2.69                  74
# 133   1445.815126   536.848739         2.69                  75
# 134   1451.924370   538.756303         2.69                  76
# 135   1458.033613   540.663866         2.70                  77
# 136   1464.142857   470.000000         3.12                  78
# 137   1470.252101   379.000000         3.88                  79
# 138   1476.361345   575.000000         2.57                  80
# 139   1482.470588   367.000000         4.04                  81
# 140   1488.579832   502.000000         2.97                  82
# 141   1494.689076   552.109244         2.71                  83
# 142   1500.798319   554.016807         2.71                  84
# 143   1506.907563   555.924370         2.71                  85
# 144   1513.016807   557.831933         2.71                  86
# 145   1519.126050   559.739496         2.71                  87
# 146   1525.235294   575.000000         2.65                  88
# 147   1531.344538   367.000000         4.17                  89
# 148   1537.453782   502.000000         3.06                  90
# 149   1543.563025   374.000000         4.13                  91
# 150   1549.672269   575.000000         2.70                  92
# 151   1555.781513   348.000000         4.47                  93
# 152   1561.890756   398.000000         3.92                  94

# %%
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
x_column = 'him_by_temp'  # Replace 'Column_X' with the name of your x-axis column
y_column = 'Degree_of_diseas %'  # Replace 'Column_Y' with the name of your y-axis column

plt.figure(figsize=(8, 6))  # Adjust the figure size as needed
plt.scatter(df[x_column], df[y_column])  # Scatter plot for x and y columns
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.title(f'Plot of {y_column} against {x_column}')
plt.grid(True)
plt.show()

# %%
# import numpy as np

# # Assuming 'df' is your DataFrame
# column_to_check = 'him_by_temp'  # Replace 'Column_X' with the first column to check
# column_to_compare = 'sum_of_temp'  # Replace 'Column_Y' with the third column for comparison
# column_to_modify = 'Degree_of_diseas %'  # Replace 'Column_Z' with the column to change

# # Conditions based on different criteria
# condition_1 = (df[column_to_check] > 4) & (df[column_to_check] <= 5)
# condition_2 = df[column_to_check] > 3
# condition_3 = (df[column_to_check] > 2) & (df[column_to_check] <= 3)
# condition_4 = df[column_to_check] < 2

# # For values between 2 and 3 in 'Column_X', apply conditions based on 'Column_Y'
# df.loc[condition_3 & (df[column_to_compare] > 430), column_to_modify] = 0
# df.loc[(condition_3) & (df[column_to_compare] < 430) & (df[column_to_compare] > 390), column_to_modify] = np.random.randint(50, 56, size=sum((condition_3) & (df[column_to_compare] < 430) & (df[column_to_compare] > 390)))
# df.loc[(condition_3) & (df[column_to_compare] < 390), column_to_modify] = np.random.randint(53, 68, size=sum((condition_3) & (df[column_to_compare] < 390)))

# # Other conditions remain the same as the previous example

# # Display the modified DataFrame
# print(df)
# Out:
#      Sum_of_humid  sum_of_temp  him_by_temp  Degree_of_diseas %
# 0      869.000000        429.0         2.03                  55
# 1      938.000000        470.0         2.00                   0
# 2     1542.000000        379.0         4.07                  62
# 3      852.000000        575.0         1.48                   0
# 4     1503.000000        367.0         4.10                  70
# ..            ...          ...          ...                 ...
# 148   1537.453782        502.0         3.06                  56
# 149   1543.563025        374.0         4.13                  64
# 150   1549.672269        575.0         2.70                   0
# 151   1555.781513        348.0         4.47                  72
# 152   1561.890756        398.0         3.92                  75
#
# [153 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

data = {
    'Sum_of_humid': [869, 938, 1542, 852, 1503, 1151, 1437, 841, 1568, 1255, 1119, 1254, 949, 1325, 1158],
    'sum_of_temp': [429, 470, 379, 575, 367, 502, 374, 575, 348, 398, 438, 469, 471, 433, 373],
    'him_by_temp': [2.02, 1.99, 4.06, 1.48, 4.10, 2.29, 3.84, 1.46, 4.51, 3.15, 2.55, 2.67, 2.01, 3.06, 3.10],
    'Degree_of_diseas %': [0, 0, 68, 0, 58, 53, 61, 0, 93, 73, 0, 0, 0, 0, 52]
}

# Extracting data
x = data['Sum_of_humid']
y = data['sum_of_temp']
disease_percentage = data['Degree_of_diseas %']

# Creating a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x, y, s=disease_percentage, c=disease_percentage, cmap='RdYlGn', alpha=0.7, edgecolors='w', linewidths=1.5)

# Adding labels and title
plt.xlabel('Sum of Humidity')
plt.ylabel('Sum of Temperature')
plt.title('Relationship between Humidity, Temperature, and Disease Percentage')

# Adding a colorbar to represent disease percentage
plt.colorbar(label='Disease Percentage')

# Display the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Croping = df

# %%
Croping.shape
# Out:
# (15, 4)

# %%
Croping.head()
# Out:
#    Sum_of_humid  sum_of_temp  him_by_temp  Degree_of_diseas %
# 0           869          429         2.02                   0
# 1           938          470         1.99                   0
# 2          1542          379         4.06                  68
# 3           852          575         1.48                   0
# 4          1503          367         4.10                  58

# %%
Croping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sum_of_humid        15 non-null     int64
#  1   sum_of_temp         15 non-null     int64
#  2   him_by_temp         15 non-null     float64
#  3   Degree_of_diseas %  15 non-null     int64
# dtypes: float64(1), int64(3)
# memory usage: 612.0 bytes

# %%
Croping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sum_of_humid        15 non-null     int64
#  1   sum_of_temp         15 non-null     int64
#  2   him_by_temp         15 non-null     float64
#  3   Degree_of_diseas %  15 non-null     int64
# dtypes: float64(1), int64(3)
# memory usage: 612.0 bytes

# %%
Croping.describe()
# Out:
#        Sum_of_humid  sum_of_temp  him_by_temp  Degree_of_diseas %
# count     15.000000    15.000000    15.000000           15.000000
# mean    1184.066667   440.066667     2.819333           30.533333
# std      256.353681    71.360720     0.975555           35.067011
# min      841.000000   348.000000     1.460000            0.000000
# 25%      943.500000   376.500000     2.015000            0.000000
# 50%     1158.000000   433.000000     2.670000            0.000000
# 75%     1381.000000   470.500000     3.495000           59.500000
# max     1568.000000   575.000000     4.510000           93.000000

# %%
Croping.hist(bins=50,figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'Sum_of_humid'}>,
#         <Axes: title={'center': 'sum_of_temp'}>],
#        [<Axes: title={'center': 'him_by_temp'}>,
#         <Axes: title={'center': 'Degree_of_diseas %'}>]], dtype=object)

# %%
Croping.corr()
# Out:
#                     Sum_of_humid  sum_of_temp  him_by_temp  Degree_of_diseas %
# Sum_of_humid            1.000000    -0.787119     0.968715            0.763127
# sum_of_temp            -0.787119     1.000000    -0.891170           -0.692434
# him_by_temp             0.968715    -0.891170     1.000000            0.811830
# Degree_of_diseas %      0.763127    -0.692434     0.811830            1.000000

# %%
corr_matrix=Croping.corr()
corr_matrix["Degree_of_diseas %"].sort_values(ascending=False)
# Out:
# Degree_of_diseas %    1.000000
# him_by_temp           0.811830
# Sum_of_humid          0.763127
# sum_of_temp          -0.692434
# Name: Degree_of_diseas %, dtype: float64

# %%
X = Croping.drop(['Degree_of_diseas %', 'him_by_temp'], axis=1)
y = Croping['Degree_of_diseas %']  # Selecting the 'Degree_of_diseas %' column

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, 
                                                    test_size = 0.2, 
                                                    random_state=1984)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Assuming X_train and y_train are your training data
# X_train should be a NumPy array or Pandas DataFrame with features
# y_train should be a NumPy array or Pandas Series with the target variable

# Create a neural network model
model = Sequential()

# Add a dense layer with ReLU activation (adjust the number of units as needed)
model.add(Dense(32, input_shape=(X_train.shape[1],), activation='relu'))
# Add another dense layer (you can add more layers as necessary)
model.add(Dense(16, activation='relu'))
# Output layer with one unit for regression
model.add(Dense(1))

# Compile the model with an optimizer and a loss function for regression (e.g., mean squared error)
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)  # Adjust parameters as needed

# Evaluate the model
loss = model.evaluate(X_test, y_test)  # Assuming you have test data X_test, y_test

# Predict using the trained model
predictions = model.predict(X_test)
# Out:
# 2023-11-11 17:48:57.067983: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-11 17:48:57.108786: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-11 17:48:57.280459: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-11 17:48:57.280486: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-11 17:48:57.281586: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-11 17:48:57.379729: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-11 17:48:57.380814: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-11 17:48:58.300984: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Epoch 1/50
# 2023-11-11 17:49:00.813893: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 1/1 [==============================] - 1s 554ms/step - loss: 23035.4648 - val_loss: 21988.5059
# Epoch 2/50
# 1/1 [==============================] - 0s 17ms/step - loss: 18105.0547 - val_loss: 17883.7285
# Epoch 3/50
# 1/1 [==============================] - 0s 16ms/step - loss: 13853.4404 - val_loss: 14252.3516
# Epoch 4/50
# 1/1 [==============================] - 0s 16ms/step - loss: 10226.2432 - val_loss: 11099.9609
# Epoch 5/50
# 1/1 [==============================] - 0s 16ms/step - loss: 7234.6084 - val_loss: 8425.3760
# Epoch 6/50
# 1/1 [==============================] - 0s 16ms/step - loss: 4883.6660 - val_loss: 6226.4390
# Epoch 7/50
# 1/1 [==============================] - 0s 15ms/step - loss: 3166.7036 - val_loss: 4477.0112
# Epoch 8/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1998.1641 - val_loss: 3047.1875
# Epoch 9/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1302.5957 - val_loss: 2016.1621
# Epoch 10/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1015.6519 - val_loss: 1328.7551
# Epoch 11/50
# 1/1 [==============================] - 0s 18ms/step - loss: 1061.5630 - val_loss: 916.8824
# Epoch 12/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1333.7075 - val_loss: 694.2986
# Epoch 13/50
# 1/1 [==============================] - 0s 17ms/step - loss: 1718.2427 - val_loss: 593.5302
# Epoch 14/50
# 1/1 [==============================] - 0s 16ms/step - loss: 2113.6184 - val_loss: 558.2457
# Epoch 15/50
# 1/1 [==============================] - 0s 16ms/step - loss: 2444.7161 - val_loss: 546.6599
# Epoch 16/50
# 1/1 [==============================] - 0s 16ms/step - loss: 2662.1479 - val_loss: 533.0253
# Epoch 17/50
# 1/1 [==============================] - 0s 16ms/step - loss: 
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 26
#      23 model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)  # Adjust parameters as needed
#      25 # Evaluate the model
# ---> 26 loss = model.evaluate(X_test, y_test)  # Assuming you have test data X_test, y_test
#      28 # Predict using the trained model
#      29 predictions = model.predict(X_test)
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /tmp/__autograph_generated_filehm5a579k.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__test_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "/home/atamuratov_e/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py", line 2042, in test_function  *
#         return step_function(self, iterator)
#     File "/home/atamuratov_e/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py", line 2025, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/atamuratov_e/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py", line 2013, in run_step  **
#         outputs = model.test_step(data)
#     File "/home/atamuratov_e/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py", line 1893, in test_step
#         y_pred = self(x, training=False)
#     File "/home/atamuratov_e/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/home/atamuratov_e/anaconda3/lib/python3.11/site-packages/keras/src/engine/input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential" is incompatible with the layer: expected shape=(None, 3), found shape=(None, 2)

# %%
from sklearn.linear_model import LinearRegression 
OLS = LinearRegression()
OLS.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#display the intercept and coefficient
print(" the intercept is " +  str(OLS.intercept_))
print(" the coeffiients are " +  str(OLS.coef_))
print(" the R_sqaured value is " +  str(OLS.score(X_train, y_train)))
# Out:
#  the intercept is -89.0183737722158
#  the coeffiients are [ 0.11186418 -0.02297505]
#  the R_sqaured value is 0.7121849609551945

# %%
#predicting with OLS
y_pred=OLS.predict(X_test)
performance = pd.DataFrame({'PREDICTIONS': y_pred, 'ACTUAL VALUES':y_test})
performance.head()
performance['error']=performance['ACTUAL VALUES']-performance['PREDICTIONS']
performance.head()
# Out:
#     PREDICTIONS  ACTUAL VALUES      error
# 13    49.253466              0 -49.253466
# 4     70.681642             58 -12.681642
# 14    31.950651             52  20.049349

# %%
#preparing data for plotting
performance.reset_index(drop=True, inplace=True) #inplace turns into a column
performance.reset_index(inplace=True)
performance.head()
# Out:
#    index  PREDICTIONS  ACTUAL VALUES      error
# 0      0    49.253466              0 -49.253466
# 1      1    70.681642             58 -12.681642
# 2      2    31.950651             52  20.049349

# %%
#plot the residuals
fig = plt.figure(figsize=(10,5))
plt.bar('index', 'error', data=performance[:50], color='black', width=0.3)
plt.ylabel('residuals')
plt.xlabel('observations')
plt.show()

# %%
import statsmodels.api as sm
X_train = sm.add_constant(X_train)
X_train.head()
# Out:
#     const  Sum_of_humid  sum_of_temp
# 10    1.0          1119          438
# 0     1.0           869          429
# 7     1.0           841          575
# 1     1.0           938          470
# 2     1.0          1542          379

# %%
nicer_OLS=sm.OLS(y_train,X_train).fit()
nicer_OLS.summary()
# Out:
# /home/atamuratov_e/anaconda3/lib/python3.11/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Degree_of_diseas %   R-squared:                       0.712
# Model:                            OLS   Adj. R-squared:                  0.648
# Method:                 Least Squares   F-statistic:                     11.14
# Date:                Sat, 11 Nov 2023   Prob (F-statistic):            0.00368
# Time:                        17:43:16   Log-Likelihood:                -52.356
# No. Observations:                  12   AIC:                             110.7
# Df Residuals:                       9   BIC:                             112.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -89.0184    110.906     -0.803      0.443    -339.905     161.868
# Sum_of_humid     0.1119      0.042      2.679      0.025       0.017       0.206
# sum_of_temp     -0.0230      0.151     -0.152      0.883      -0.365       0.319
# ==============================================================================
# Omnibus:                        1.089   Durbin-Watson:                   2.080
# Prob(Omnibus):                  0.580   Jarque-Bera (JB):                0.401
# Skew:                          -0.443   Prob(JB):                        0.818
# Kurtosis:                       2.870   Cond. No.                     2.20e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.2e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
